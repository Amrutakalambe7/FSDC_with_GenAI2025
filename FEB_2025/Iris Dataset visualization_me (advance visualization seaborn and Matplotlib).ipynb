# %% [markdown]
# ## Importing Libararies

# %%
import numpy as np
import pandas as  pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Dataset (Extract Dataset)

# %%
iris = pd.read_csv(r'E:\Naresh IT Data Science Course\Sep Month course Material\7th Sep\7th\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# view dataset

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.drop('Id',axis=1,inplace=True)

# %%
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.isnull()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
iris.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# Plot Graph

# %%
c= sns.countplot(data=iris,x='Species')
c
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig = sns.jointplot(data=iris,x='SepalLengthCm',y='SepalWidthCm')
fig

# %%
fig = sns.jointplot(data=iris,x='SepalLengthCm',y='SepalWidthCm',kind='reg')
fig

# %%
fig = sns.jointplot(data=iris,x='SepalLengthCm',y='SepalWidthCm',kind="hex")
fig

# %%
FacetGrid Plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.FacetGrid(iris,hue='Species',height=5)\
.map(plt.scatter,'SepalLengthCm','SepalWidthCm')\
.add_legend()

# %%
fig= plt.gcf() # .gcf() = get the current figure
fig.set_size_inches(10,8)
fig=sns.boxplot(data=iris,x='Species',y='SepalLengthCm',order=['Iris-virginica','Iris-versicolor','Iris-setosa'],orient='v',dodge=False)
fig
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
iris.boxplot(by='Species',figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Strip plot

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig = sns.stripplot(data=iris,x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')
fig
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %% [markdown]
# 8. Combining Box and Strip Plots

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(data=iris,x='Species',y='SepalLengthCm')
fig = sns.stripplot(data=iris,x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray')

# %%
ax= sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax= sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")

boxtwo = ax.artists[2]
boxtwo.set_facecolor('yellow')
boxtwo.set_edgecolor('black')
boxthree=ax.artists[1]
boxthree.set_facecolor('red')
boxthree.set_edgecolor('black')
boxthree=ax.artists[0]
boxthree.set_facecolor('green')
boxthree.set_edgecolor('black')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 4
#       1 ax= sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
#       2 ax= sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")
# ----> 4 boxtwo = ax.artists[2]
#       5 boxtwo.set_facecolor('yellow')
#       6 boxtwo.set_edgecolor('black')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:1457, in _AxesBase.ArtistList.__getitem__(self, key)
#    1456 def __getitem__(self, key):
# -> 1457     return [artist
#    1458             for artist in self._axes._children
#    1459             if self._type_check(artist)][key]
#
# IndexError: list index out of range

# %%
Violin Plot

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.violinplot(x='Species',y='SepalLengthCm',data=iris)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
Pair Plot

# %%
sns.pairplot(data=iris,kind='scatter')

# %%
sns.pairplot(data=iris,hue='Species')

# %%
Heat Map

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.heatmap(iris.corr(),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)
