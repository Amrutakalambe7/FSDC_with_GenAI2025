# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Amruta'

# %%
movies = pd.read_csv(r'E:\Naresh IT Data Science Course\Sep Month course Material\7th Sep\7th\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv')
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre','CriticRating','AudienceRating','BudgetMillion','Year']
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillion',
#        'Year'],
#       dtype='object')

# %%
movies #removed additional space and noisy charecters
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillion  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# ...

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillion   559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion         Year
# count    559.000000      559.000000     559.000000   559.000000
# mean      47.309481       58.744186      50.236136  2009.152057
# std       26.413091       16.826887      48.731817     1.362632
# min        0.000000        0.000000       0.000000  2007.000000
# 25%       25.000000       47.000000      20.000000  2008.000000
# 50%       46.000000       58.000000      35.000000  2009.000000
# 75%       70.000000       72.000000      65.000000  2010.000000
# max       97.000000       96.000000     300.000000  2011.000000

# %%
movies['Film'] = movies['Film'].astype('category')
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillion   559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies['Genre'] = movies['Genre'].astype('category')
movies['Year'] = movies['Year'].astype('category')

# %%
movies['Genre']
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies['Year']
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillion   559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion
# count    559.000000      559.000000     559.000000
# mean      47.309481       58.744186      50.236136
# std       26.413091       16.826887      48.731817
# min        0.000000        0.000000       0.000000
# 25%       25.000000       47.000000      20.000000
# 50%       46.000000       58.000000      35.000000
# 75%       70.000000       72.000000      65.000000
# max       97.000000       96.000000     300.000000

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillion  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# ...

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %% [markdown]
# ## Visualization

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
j=sns.jointplot(data=movies,x ='CriticRating',y='AudienceRating')
j

# %%
j1=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='hex')
j1

# %%
j2=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='reg')
j2

# %%
m1 = sns.distplot(movies.AudienceRating) # Distribution Plot
m1
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Density'>

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.AudienceRating,bins = 15)
m2
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Density'>

# %%
n1 = plt.hist(movies.AudienceRating, bins = 15)
n1
# Out:
# (array([ 2.,  0.,  1.,  5., 20., 42., 48., 81., 76., 65., 67., 60., 45.,
#         35., 12.]),
#  array([ 0. ,  6.4, 12.8, 19.2, 25.6, 32. , 38.4, 44.8, 51.2, 57.6, 64. ,
#         70.4, 76.8, 83.2, 89.6, 96. ]),
#  <BarContainer object of 15 artists>)

# %%
sns.set_style('white')
n2 = plt.hist(movies.AudienceRating, bins = 20)  ##normal distribution & called as bell curve
n2
# Out:
# (array([ 2.,  0.,  0.,  1.,  2., 12., 18., 35., 40., 41., 61., 63., 52.,
#         53., 33., 54., 34., 30., 23.,  5.]),
#  array([ 0. ,  4.8,  9.6, 14.4, 19.2, 24. , 28.8, 33.6, 38.4, 43.2, 48. ,
#         52.8, 57.6, 62.4, 67.2, 72. , 76.8, 81.6, 86.4, 91.2, 96. ]),
#  <BarContainer object of 20 artists>)

# %%
n4 = plt.hist(movies.CriticRating, bins = 20) #uniform distribution
n4
# Out:
# (array([13., 25., 36., 28., 36., 39., 21., 32., 37., 31., 36., 28., 22.,
#         21., 29., 25., 28., 29., 22., 21.]),
#  array([ 0.  ,  4.85,  9.7 , 14.55, 19.4 , 24.25, 29.1 , 33.95, 38.8 ,
#         43.65, 48.5 , 53.35, 58.2 , 63.05, 67.9 , 72.75, 77.6 , 82.45,
#         87.3 , 92.15, 97.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Creating stacked histograms & this is bit tough to understand

# %%
plt.hist(movies.BudgetMillion)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillion)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Adventure'].BudgetMillion)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillion)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
# Below plots are stacked histogram becuase overlaped
plt.hist(movies[movies.Genre =='Action'].BudgetMillion,bins = 20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillion, bins = 20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillion, bins = 20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([movies[movies.Genre =='Action'].BudgetMillion,\
          movies[movies.Genre =='Thriller'].BudgetMillion,\
          movies[movies.Genre =='Drama'].BudgetMillion,\
          movies[movies.Genre =='Comedy'].BudgetMillion],bins = 20, stacked = True)
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating',fit_reg = False)
vis1

# %%
vis1 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating',fit_reg = False,hue ='Genre')
vis1

# %%
vis1 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating',\
                  fit_reg = False,hue ='Genre',height =8,aspect=1)
vis1

# %% [markdown]
# # Kernal Density Estimate plot ( KDE PLOT)
# # how can i visulize audience rating & critics rating . using scatterplot

# %%
k1 = sns.kdeplot(data = movies, x= 'CriticRating',y='AudienceRating')
k1
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillion',
#        'Year'],
#       dtype='object')

# %%
k1 = sns.kdeplot(data=movies, x= 'CriticRating', y= 'AudienceRating',shade = True,shade_lowest=False,gridsize=150,cmap='Reds')
k1
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
k1 = sns.kdeplot(data=movies, x= 'CriticRating', y= 'AudienceRating',\
                 shade = True,gridsize=150,shade_lowest=False,cmap='Greens_r')
k1
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
sns.set_style('dark')
sns.kdeplot(data=movies, x= 'CriticRating', y= 'AudienceRating',\
                 shade = True,gridsize=150,shade_lowest=False,cmap='Greens_r')
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
sns.set_style('dark')
sns.kdeplot(data = movies, x= 'BudgetMillion',y='AudienceRating')
# Out:
# <Axes: xlabel='BudgetMillion', ylabel='AudienceRating'>

# %%
k2 = sns.kdeplot(data = movies, x= 'BudgetMillion',y='CriticRating')
k2
# Out:
# <Axes: xlabel='BudgetMillion', ylabel='CriticRating'>

# %%
f, ax = plt.subplots(1,2, figsize = (12,6))
f, ax = plt.subplots(3,3, figsize =(12,6))

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))
k1 = sns.kdeplot(data=movies, x='BudgetMillion', y='AudienceRating',ax=axes[0])
k2 = sns.kdeplot(data=movies, x='BudgetMillion', y='CriticRating',ax=axes[1])
k2
# Out:
# <Axes: xlabel='BudgetMillion', ylabel='CriticRating'>

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillion', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillion', ylabel='CriticRating'>],
#       dtype=object)

# %%
#box plots
w = sns.boxplot(data=movies,x='Genre',y='CriticRating')
w
# Out:
# <Axes: xlabel='Genre', ylabel='CriticRating'>

# %%
v=sns.violinplot(data=movies,x='Genre',y='CriticRating')
v
# Out:
# <Axes: xlabel='Genre', ylabel='CriticRating'>

# %%
w1 = sns.boxplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating')
w1
# Out:
# <Axes: xlabel='Year', ylabel='CriticRating'>

# %%
v1= sns.violinplot(data=movies[movies.Genre=='Action'],x='Year',y='CriticRating')
v1
# Out:
# <Axes: xlabel='Year', ylabel='CriticRating'>

# %%
v2=v1= sns.violinplot(data=movies[movies.Genre=='Action'],x='Year',y='AudienceRating')
v2
# Out:
# <Axes: xlabel='Year', ylabel='AudienceRating'>

# %%
#creating Facetgrid
f1 = sns.FacetGrid(data=movies,row='Genre',col='Year',hue='Genre')
f1

# %%
#plt.scatter(movies.CriticRating, movies.AudienceRating)
plt.scatter(data=movies,x= 'CriticRating',y= 'AudienceRating')

# %%
g = sns.FacetGrid(movies,row = 'Genre',col = 'Year',hue = 'Genre')
g= g.map(plt.scatter, 'CriticRating','AudienceRating') #scatterplots are mapped in facetgrid
g

# %%
g1 = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue ='Genre')
g1 = g1.map(plt.hist, 'BudgetMillion')  #scatterplots are mapped in facetgrid
g1

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws )

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(data = movies, x= 'BudgetMillion',y='AudienceRating',ax = axes[0,0])
k2 = sns.kdeplot(data = movies, x= 'BudgetMillion',y='CriticRating',ax = axes[0,1])

#k1.set(xlim=(-20,160))
#k2.set(xlim=(-20,160))

z= sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])
k4 = sns.kdeplot(data = movies, x = 'CriticRating',y = 'AudienceRating',shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
k4b = sns.kdeplot(data = movies,x = 'CriticRating',y = 'AudienceRating',cmap='Reds',ax = axes[1,1])
plt.show()

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot[0,0]
k1 = sns.kdeplot(data = movies, x= 'BudgetMillion',y='AudienceRating',\
                 shade = True, shade_lowest=True,ax = axes[0,0])
k1b = sns.kdeplot(data = movies, x= 'BudgetMillion',y='AudienceRating',\
                shade = True, shade_lowest=True,color = 'blue', ax = axes[0,0])


#plot [0,0]
k2 = sns.kdeplot(data = movies, x= 'BudgetMillion',y='CriticRating',\
                shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(data = movies, x= 'BudgetMillion',y='CriticRating',\
                  cmap = 'cool', ax = axes[0,1])

#plot [1,0]
z= sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(data = movies, x = 'CriticRating',y = 'AudienceRating',\
                 shade = True,shade_lowest=False,cmap='Blues_r',\
                 ax=axes[1,1])
k4b = sns.kdeplot(data = movies,x = 'CriticRating',y = 'AudienceRating',\
                  cmap='gist_gray_r',ax = axes[1,1])

#k1.set(xlim=(-20,160))
#k2.set(xlim=(-20,160))

plt.show()
